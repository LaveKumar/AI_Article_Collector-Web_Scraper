# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://content.guardianapis.com/technology/artificialintelligenceai?&api-key=01dd6b39-66d5-4ed8-8335-9dd17fe41a3f&type=article&page=1"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
x = response.json()

# %%
x
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 3612,
#   'startIndex': 1,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 362,
#   'orderBy': 'newest',
#   'tag': {'id': 'technology/artificialintelligenceai',
#    'type': 'keyword',
#    'sectionId': 'technology',
#    'sectionName': 'Technology',
#    'webTitle': 'Artificial intelligence (AI)',
#    'webUrl': 'https://www.theguardian.com/technology/artificialintelligenceai',
#    'apiUrl': 'https://content.guardianapis.com/technology/artificialintelligenceai'},
#   'results': [{'id': 'us-news/2025/nov/13/ai-campaign-videos-elections',
#     'type': 'article',
#     'sectionId': 'us-news',
#     'sectionName': 'US news',
#     'webPublicationDate': '2025-11-13T12:00:42Z',
#     'webTitle': 'Lies, damned lies and AI: the newest way to influence elections may be here to stay',
#     'webUrl': 'https://www.theguardian.com/us-news/2025/nov/13/ai-campaign-videos-elections',
#     'apiUrl': 'https://content.guardianapis.com/us-news/2025/nov/13/ai-campaign-videos-elections',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'us-news/2025/nov/12/elon-musk-grok-ai-trump-2020-presidential-election',
#     'type': 'article',
#     'sectionId': 'us-news',
#     'sectionName': 'US news',
#     'webPublicationDate': '2025-11-12T23:22:47Z',
#     'webTitle': 'Elon Musk’s Grok AI briefly says Trump won 2020 presidential election',
#     'webUrl': 'https://www.theguardian.com/us-news/2025/nov/12/elon-musk-grok-ai-trump-2020-presidential-election',
#     'apiUrl': 'https://content.guardianapis.com/us-news/2025/nov/12/elon-musk-grok-ai-trump-2020-presidential-election',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-12T22:29:49Z',
#     'webTitle': 'Anthropic announces $50bn plan for datacenter construction in US',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'australia-news/2025/nov/12/government-using-machine-learning-to-help-create-draft-plans-for-ndis-participants-documents-reveal',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2025-11-12T14:00:56Z',
#     'webTitle': 'Government using machine learning to help create draft plans for NDIS participants, documents reveal',
#     'webUrl': 'https://www.theguardian.com/australia-news/2025/nov/12/government-using-machine-learning-to-help-create-draft-plans-for-ndis-participants-documents-reveal',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2025/nov/12/government-using-machine-learning-to-help-create-draft-plans-for-ndis-participants-documents-reveal',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2025/nov/12/eu-gdpr-data-law-us-tech-giants-digital',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2025-11-12T05:00:15Z',
#     'webTitle': 'The EU has let US tech giants run riot. Diluting our data law will only entrench their power | Johnny Ryan and Georg Riekeles',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2025/nov/12/eu-gdpr-data-law-us-tech-giants-digital',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2025/nov/12/eu-gdpr-data-law-us-tech-giants-digital',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'australia-news/2025/nov/12/australian-government-ai-cabinet-submissions',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2025-11-12T04:03:34Z',
#     'webTitle': 'Australian government could explore using AI for cabinet submissions despite security concerns',
#     'webUrl': 'https://www.theguardian.com/australia-news/2025/nov/12/australian-government-ai-cabinet-submissions',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2025/nov/12/australian-government-ai-cabinet-submissions',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-12T00:01:10Z',
#     'webTitle': 'Tech companies and UK child safety agencies to test AI tools’ ability to create abuse images',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'society/2025/nov/11/children-being-sedated-by-algorithmic-youtube-content-mps-hear',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2025-11-11T19:25:41Z',
#     'webTitle': 'Children being ‘sedated’ by algorithmic YouTube content, MPs hear',
#     'webUrl': 'https://www.theguardian.com/society/2025/nov/11/children-being-sedated-by-algorithmic-youtube-content-mps-hear',
#     'apiUrl': 'https://content.guardianapis.com/society/2025/nov/11/children-being-sedated-by-algorithmic-youtube-content-mps-hear',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-11T18:10:29Z',
#     'webTitle': 'Matthew McConaughey and Michael Caine sign voice deal with AI company',
#     'webUrl': 'https://www.theguardian.com/culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'apiUrl': 'https://content.guardianapis.com/culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'business/2025/nov/11/softbank-sells-stake-in-nvidia-as-it-doubles-down-on-openai-bets',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2025-11-11T16:44:33Z',
#     'webTitle': 'SoftBank sells stake in Nvidia for $5.8bn as it doubles down on OpenAI bets',
#     'webUrl': 'https://www.theguardian.com/business/2025/nov/11/softbank-sells-stake-in-nvidia-as-it-doubles-down-on-openai-bets',
#     'apiUrl': 'https://content.guardianapis.com/business/2025/nov/11/softbank-sells-stake-in-nvidia-as-it-doubles-down-on-openai-bets',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'}],
#   'leadContent': [{'id': 'technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-12T22:29:49Z',
#     'webTitle': 'Anthropic announces $50bn plan for datacenter construction in US',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/12/anthropic-50bn-datacenter-construction',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-12T00:01:10Z',
#     'webTitle': 'Tech companies and UK child safety agencies to test AI tools’ ability to create abuse images',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-11T18:10:29Z',
#     'webTitle': 'Matthew McConaughey and Michael Caine sign voice deal with AI company',
#     'webUrl': 'https://www.theguardian.com/culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'apiUrl': 'https://content.guardianapis.com/culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/10/data-centers-latin-america',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-10T23:58:06Z',
#     'webTitle': 'Datacenters meet resistance over environmental concerns as AI boom spreads in Latin America',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/10/data-centers-latin-america',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/10/data-centers-latin-america',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/05/amazon-perplexity-ai-lawsuit',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-05T16:17:44Z',
#     'webTitle': 'Amazon sues AI startup over browser’s automated shopping and buying feature',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/05/amazon-perplexity-ai-lawsuit',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/05/amazon-perplexity-ai-lawsuit',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/04/experts-find-flaws-hundreds-tests-check-ai-safety-effectiveness',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-04T00:05:13Z',
#     'webTitle': 'Experts find flaws in hundreds of tests that check AI safety and effectiveness',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/04/experts-find-flaws-hundreds-tests-check-ai-safety-effectiveness',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/04/experts-find-flaws-hundreds-tests-check-ai-safety-effectiveness',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/03/grokipedia-academics-assess-elon-musk-ai-powered-encyclopedia',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-03T06:00:23Z',
#     'webTitle': 'In Grok we don’t trust: academics assess Elon Musk’s AI-powered encyclopedia ',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/03/grokipedia-academics-assess-elon-musk-ai-powered-encyclopedia',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/03/grokipedia-academics-assess-elon-musk-ai-powered-encyclopedia',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/nov/02/global-datacentre-boom-investment-debt',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-11-02T12:00:02Z',
#     'webTitle': 'Boom or bubble? Inside the $3tn AI datacentre spending spree',
#     'webUrl': 'https://www.theguardian.com/technology/2025/nov/02/global-datacentre-boom-investment-debt',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/nov/02/global-datacentre-boom-investment-debt',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/oct/30/teenage-boys-using-personalised-ai-for-therapy-and-romance-survey-finds',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-10-30T00:01:46Z',
#     'webTitle': 'Teenage boys using ‘personalised’ AI for therapy and romance, survey finds',
#     'webUrl': 'https://www.theguardian.com/technology/2025/oct/30/teenage-boys-using-personalised-ai-for-therapy-and-romance-survey-finds',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/oct/30/teenage-boys-using-personalised-ai-for-therapy-and-romance-survey-finds',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2025/oct/29/character-ai-suicide-children-ban',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2025-10-29T16:07:25Z',
#     'webTitle': 'Character.AI bans users under 18 after being sued over child’s suicide',
#     'webUrl': 'https://www.theguardian.com/technology/2025/oct/29/character-ai-suicide-children-ban',
#     'apiUrl': 'https://content.guardianapis.com/technology/2025/oct/29/character-ai-suicide-children-ban',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'}]}}

# %%
web_urls = [item['webUrl'] for item in x['response']['results']]

for url in web_urls:
    print(url)
    print("\n")
# Out:
# https://www.theguardian.com/us-news/2025/nov/13/ai-campaign-videos-elections
#
#
# https://www.theguardian.com/us-news/2025/nov/12/elon-musk-grok-ai-trump-2020-presidential-election
#
#
# https://www.theguardian.com/technology/2025/nov/12/anthropic-50bn-datacenter-construction
#
#
# https://www.theguardian.com/australia-news/2025/nov/12/government-using-machine-learning-to-help-create-draft-plans-for-ndis-participants-documents-reveal
#
#
# https://www.theguardian.com/commentisfree/2025/nov/12/eu-gdpr-data-law-us-tech-giants-digital
#
#
# https://www.theguardian.com/australia-news/2025/nov/12/australian-government-ai-cabinet-submissions
#
#
# https://www.theguardian.com/technology/2025/nov/12/tech-companies-child-safety-agencies-test-ai-tools-abuse-images-ability
#
#
# https://www.theguardian.com/society/2025/nov/11/children-being-sedated-by-algorithmic-youtube-content-mps-hear
#
#
# https://www.theguardian.com/culture/2025/nov/11/matthew-mcconaughey-michael-caine-ai-voice
#
#
# https://www.theguardian.com/business/2025/nov/11/softbank-sells-stake-in-nvidia-as-it-doubles-down-on-openai-bets

# %%
import os
from datetime import datetime

current_datetime = datetime.now()
folder_name = current_datetime.strftime('%H_%M_%d_%m_%Y')

if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
def save_content_to_file(url, folder, filename):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup  = BeautifulSoup(response.text, 'html.parser')
            
            with open(os.path.join(folder, filename), 'w', encoding='utf-8') as file:
                for header in soup.find_all(['h1']):
                    file.write("Tile: " + header.text + '\n'*5)
                for paragraph in soup.find_all('p'):
                    file.write(paragraph.text + '\n')
        else:
            print("Failed to retrieve the page:", url)
    except Exception as e:
        print("An Error Occurred:", e)

for index, url in enumerate(web_urls):
    filename = f'article_{index}.txt' 
    save_content_to_file(url, folder_name, filename)

print("Executed Successfully BOOM!...")
# Out:
# Executed Successfully BOOM!...
